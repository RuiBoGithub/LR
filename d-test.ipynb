# %% [markdown]
# In notebooks, always use `!pip install package_name`. In the terminal, use `pip install package_name`.
#
# - `!pip` is used **inside Jupyter notebooks** or IPython environments to run shell commands (like installing packages) from a code cell.
# - `pip` (without the exclamation mark) is used **in the terminal/command prompt** or in scripts, not inside notebook cells.

# %%
import os, json, yaml
import pandas as pd
from tqdm import tqdm
from gensim.models import Word2Vec
import classify_papers as cp
with open("ontology.yaml", "r", encoding="utf-8") as f:
    ont = yaml.safe_load(f) or {}

w2v = Word2Vec.load("word2vec_model.model")
ont_expanded = cp.expand_ontology(w2v, ont)
kpi_priority = list(ont.get("kpi_resolution", {}).keys())
input_priority = list(ont.get("input_resolution", {}).keys())
input_dir = "papers_json"
results = []

for fname in tqdm(os.listdir(input_dir), desc="Classifying papers"):
    if not fname.endswith(".json"):
        continue
    with open(os.path.join(input_dir, fname), "r", encoding="utf-8") as f:
        doc = json.load(f)
    res = cp.analyze_paper(doc, ont_expanded, kpi_priority, input_priority)
    results.append({"file": fname, **res})

df = pd.DataFrame(results)
df.head()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\s2589602\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\s2589602\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Classifying papers: 100%|██████████| 27/27 [30:47<00:00, 68.41s/it]
#                              file             paradigms  \
# 0  10.1016_j.scs.2021.102792.json            [blackbox]
# 1  10.1016_j.scs.2021.102816.json  [whitebox, blackbox]
# 2  10.1016_j.scs.2021.102832.json  [whitebox, blackbox]
# 3  10.1016_j.scs.2021.102972.json            [blackbox]
# 4  10.1016_j.scs.2021.103001.json            [blackbox]
#
#                                      paradigm_scores  \
# 0  {'whitebox': 0.0, 'greybox': 0.0, 'blackbox': ...
# 1  {'whitebox': 3.0, 'greybox': 0.0, 'blackbox': ...
# 2  {'whitebox': 2.0, 'greybox': 0.0, 'blackbox': ...
# 3  {'whitebox': 0.0, 'greybox': 0.0, 'blackbox': ...
# 4  {'whitebox': 0.0, 'greybox': 0.0, 'blackbox': ...
#
#                                           model_hits  \
# 0          {'neural network': 0.5, 'recurrent': 0.5}
# 1  {'nonlinear processes': 0.5, 'open-source': 0....
# 2  {'control-oriented': 0.5, 'energyplus': 0.5, '...
# 3                               {'data-driven': 0.5}
# 4  {'decision trees': 0.5, 'k-nearest': 0.5, 'knn...
#
#                                       model_evidence  \
# 0  {'neural network': [('preamble', 'neural netwo...
# 1  {'nonlinear processes': [('preamble', 'nonline...
# 2  {'control-oriented': [('preamble', 'control-or...
# 3  {'data-driven': [('preamble', 'data-driven', '...
# 4  {'decision trees': [('preamble', 'decision tre...
#
#                                     scale  \
# 0  [building, climate, occupancy, system]
# 1           [building, occupancy, system]
# 2  [building, climate, occupancy, system]
# 3  [building, climate, occupancy, system]
# 4          [building, climate, occupancy]
#
#                                       scale_evidence  \
# 0  {'building': [('preamble', 'aggregate', 'll up...
# 1  {'building': [('preamble', 'aggregated', '48:2...
# 2  {'building': [('preamble', 'aggregate', '34 8....
# 3  {'building': [('preamble', 'aggregated', '19:2...
# 4  {'building': [('preamble', 'aggregate', 'lker ...
#
#                                           data_types  \
# 0  [air_quality, air_temperature, environment, hv...
# 1  [air_quality, air_temperature, hvac_signals, m...
# 2  [air_quality, air_temperature, environment, hv...
# 3  [air_quality, air_temperature, environment, hv...
# 4   [air_quality, hvac_signals, metering, occupancy]
#
#                                        data_evidence  \
# 0  {'metering': [('preamble', 'kw', ' s c h . , m...
# 1  {'metering': [('preamble', 'nominal', 'lothing...
# 2  {'metering': [('preamble', 'kw', '00 %-on and ...
# 3  {'metering': [('preamble', 'kva', 'c h ev disc...
# 4  {'metering': [('preamble', 'kw', '87% of the c...
#
#                                    sampling_mentions  ...  \
# 0  [{'section': 'preamble', 'value': '102681', 'u...  ...
# 1  [{'section': 'preamble', 'value': '2777', 'uni...  ...
# 2  [{'section': 'preamble', 'value': '6521', 'uni...  ...
# 3  [{'section': 'preamble', 'value': '101149', 'u...  ...
# 4  [{'section': 'preamble', 'value': '101787', 'u...  ...
#
#   collected_data_resolution kpi_types kpi_type_evidence  \
# 0                 subhourly        []                {}
# 1                 subhourly        []                {}
# 2                 subhourly        []                {}
# 3                 subhourly        []                {}
# 4                 subhourly        []                {}
#
#                                    model_development  \
# 0  [conditional, iteratively, probabilistic, real...
# 1  [multivariate, raw data, real-time, setpoints,...
# 2  [deterministic, markov chain, plug loads, real...
# 3  [markov chain, real-time, schedule, scheduled,...
# 4  [bayesian, conditional, multivariate, probabil...
#
#                           model_development_evidence  \
# 0  {'conditional': [('preamble', 'conditional', '...
# 1  {'multivariate': [('preamble', 'multivariate',...
# 2  {'deterministic': [('preamble', 'deterministic...
# 3  {'markov chain': [('preamble', 'markov chain',...
# 4  {'bayesian': [('preamble', 'bayesian', 'onal p...
#
#                                         model_inputs  \
# 0  [electric_load, electric_use, internal_gains, ...
# 1  [electric_load, electric_use, internal_gains, ...
# 2  [electric_load, electric_use, internal_gains, ...
# 3  [electric_load, electric_use, internal_gains, ...
# 4  [electric_load, electric_use, internal_gains, ...
#
#                                    input_resolutions input_resolution_primary  \
# 0  [annual, daily, hourly, monthly, subhourly, ye...                subhourly
# 1  [annual, daily, hourly, monthly, subhourly, ye...                subhourly
# 2  [annual, daily, hourly, monthly, subhourly, ye...                subhourly
# 3                [daily, hourly, monthly, subhourly]                subhourly
# 4  [annual, daily, hourly, monthly, subhourly, ye...                subhourly
#
#                                model_inputs_evidence  \
# 0  {'occupancy': [('preamble', 'absence', 't of t...
# 1  {'occupancy': [('preamble', 'occupancy', 'he c...
# 2  {'occupancy': [('preamble', 'absence', 'reas c...
# 3  {'occupancy': [('preamble', 'absence', ' throu...
# 4  {'occupancy': [('preamble', 'occupancy', ' g h...
#
#                            input_resolution_evidence
# 0  {'subhourly': [('preamble', '30-minute', 'g. 7...
# 1  {'subhourly': [('preamble', 'every', ' 2014 1 ...
# 2  {'subhourly': [('preamble', 'every', 'ation no...
# 3  {'subhourly': [('preamble', '5-minute', ' cont...
# 4  {'subhourly': [('preamble', 'every', 'ime fram...
#
# [5 rows x 25 columns]

# %%
output_csv = "classified_papers.csv"
df.to_csv(output_csv, index=False)

print(f"[OK] Wrote {output_csv} with {len(df)} rows")
# Out:
# [OK] Wrote classified_papers.csv with 27 rows
